# %% [markdown]
# This dataset contains information about various features of houses in California and their respective median prices. Key Components to be Fulfilled: Loading and Preprocessing.(2 marks): Load the California Housing dataset using the fetch_california_housing function from sklearn. Convert the dataset into a pandas DataFrame for easier handling. Handle missing values (if any) and perform necessary feature scaling (e.g., standardization).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import  fetch_california_housing

# %%
data = fetch_california_housing()

# %%
X = data.data  # Feature matrix
y = data.target  # Target vector
feature_name = data.feature_names

# %%
df = pd.DataFrame(X,columns = feature_name)
df['target'] = y

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
df['AveRooms'] = df['AveRooms'].round()
df['AveOccup'] = df['AveOccup']. round()

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0       7.0   1.023810       322.0       3.0     37.88
# 1  8.3014      21.0       6.0   0.971880      2401.0       2.0     37.86
# 2  7.2574      52.0       8.0   1.073446       496.0       3.0     37.85
# 3  5.6431      52.0       6.0   1.073059       558.0       3.0     37.85
# 4  3.8462      52.0       6.0   1.081081       565.0       2.0     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   target      20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# target        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#               count         mean          std         min         25%  \
# MedInc      20640.0     3.870671     1.899822    0.499900    2.563400
# HouseAge    20640.0    28.639486    12.585558    1.000000   18.000000
# AveRooms    20640.0     5.424806     2.491940    1.000000    4.000000
# AveBedrms   20640.0     1.096675     0.473911    0.333333    1.006079
# Population  20640.0  1425.476744  1132.462122    3.000000  787.000000
# AveOccup    20640.0     3.075727    10.387242    1.000000    2.000000
# Latitude    20640.0    35.631861     2.135952   32.540000   33.930000
# Longitude   20640.0  -119.569704     2.003532 -124.350000 -121.800000
# target      20640.0     2.068558     1.153956    0.149990    1.196000
#
#                    50%          75%           max
# MedInc         3.53480     4.743250     15.000100
# HouseAge      29.00000    37.000000     52.000000
# AveRooms       5.00000     6.000000    142.000000
# AveBedrms      1.04878     1.099526     34.066667
# Population  1166.00000  1725.000000  35682.000000
# AveOccup       3.00000     3.000000   1243.000000
# Latitude      34.26000    37.710000     41.950000
# Longitude   -118.49000  -118.010000   -114.310000
# target         1.79700     2.647250      5.000010

# %%
dfc = df.copy()

# %%
dfc.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0       7.0   1.023810       322.0       3.0     37.88
# 1  8.3014      21.0       6.0   0.971880      2401.0       2.0     37.86
# 2  7.2574      52.0       8.0   1.073446       496.0       3.0     37.85
# 3  5.6431      52.0       6.0   1.073059       558.0       3.0     37.85
# 4  3.8462      52.0       6.0   1.081081       565.0       2.0     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
dfc.isna().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# target        0
# dtype: int64

# %%
dfc.duplicated().sum()
# Out:
# 0

# %%
dfc.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0       7.0   1.023810       322.0       3.0     37.88
# 1  8.3014      21.0       6.0   0.971880      2401.0       2.0     37.86
# 2  7.2574      52.0       8.0   1.073446       496.0       3.0     37.85
# 3  5.6431      52.0       6.0   1.073059       558.0       3.0     37.85
# 4  3.8462      52.0       6.0   1.081081       565.0       2.0     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
dfc.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# target        0
# dtype: int64

# %%
dfc.describe().T
# Out:
#               count         mean          std         min         25%  \
# MedInc      20640.0     3.870671     1.899822    0.499900    2.563400
# HouseAge    20640.0    28.639486    12.585558    1.000000   18.000000
# AveRooms    20640.0     5.424806     2.491940    1.000000    4.000000
# AveBedrms   20640.0     1.096675     0.473911    0.333333    1.006079
# Population  20640.0  1425.476744  1132.462122    3.000000  787.000000
# AveOccup    20640.0     3.075727    10.387242    1.000000    2.000000
# Latitude    20640.0    35.631861     2.135952   32.540000   33.930000
# Longitude   20640.0  -119.569704     2.003532 -124.350000 -121.800000
# target      20640.0     2.068558     1.153956    0.149990    1.196000
#
#                    50%          75%           max
# MedInc         3.53480     4.743250     15.000100
# HouseAge      29.00000    37.000000     52.000000
# AveRooms       5.00000     6.000000    142.000000
# AveBedrms      1.04878     1.099526     34.066667
# Population  1166.00000  1725.000000  35682.000000
# AveOccup       3.00000     3.000000   1243.000000
# Latitude      34.26000    37.710000     41.950000
# Longitude   -118.49000  -118.010000   -114.310000
# target         1.79700     2.647250      5.000010

# %% [markdown]
# ##### There was no null values and duplicates in the dataset
# checked the presence of null values and duplicates

# %% [markdown]
# ### Removing Outliers

# %%
# collecting numerical cols together
num_columns = dfc.select_dtypes(include='number')
print(num_columns.columns)
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'target'],
#       dtype='object')

# %%
for i in num_columns.columns:
    sns.boxplot(data=dfc,x=i)
    plt.show()

# %%
# IQR Method
def outliers(dfc):
    for col in dfc.select_dtypes(include=['int64', 'float64']).columns:
        Q1 = dfc[col].quantile(0.25)
        Q3 = dfc[col].quantile(0.75)
        IQR = Q3 - Q1

        lower = Q1 - (1.5 * IQR)
        upper = Q3 + (1.5 * IQR)

        # Capping
        dfc[col] = dfc[col].apply(lambda x: lower if x < lower else upper if x > upper else x)

    return dfc

# %%
df1 = outliers(dfc)

# %%
for i in num_columns.columns:
    sns.boxplot(data = df1, x = i)
    plt.show()

# %% [markdown]
# ### Checking Skew And Removing Skewness

# %%
df1.skew()
# Out:
# MedInc        0.735618
# HouseAge      0.060331
# AveRooms      0.429236
# AveBedrms     0.462645
# Population    0.842247
# AveOccup      0.226489
# Latitude      0.465953
# Longitude    -0.297801
# target        0.912330
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt = PowerTransformer(method = 'yeo-johnson')

# %%
numerical_features = df1.select_dtypes(include=['float64', 'int64']).columns

# %%
df1[numerical_features] = pt.fit_transform(df1[numerical_features])

# %%
df1[numerical_features]
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0      2.032296  0.975968  1.266038  -0.368541   -1.646905  0.188696
# 1      2.032296 -0.568893  0.573148  -1.105422    1.313538 -1.263160
# 2      1.768880  1.761010  1.909868   0.269369   -1.213893  0.188696
# 3      1.119252  1.761010  0.573148   0.264627   -1.080540  0.188696
# 4      0.189397  1.761010  0.573148   0.362216   -1.066009 -1.263160
# ...         ...       ...       ...        ...         ...       ...
# 20635 -1.649221 -0.243556 -0.180473   0.963074   -0.550417  0.188696
# 20636 -0.709009 -0.820372  0.573148   2.021805   -1.553650  0.188696
# 20637 -1.498279 -0.905850 -0.180473   0.816317   -0.294973 -1.263160
# 20638 -1.327106 -0.820372 -0.180473   1.370891   -0.728973 -1.263160
# 20639 -0.848500 -0.992245 -0.180473   1.271527    0.226357  0.188696
#
#        Latitude     Longitude    target
# 0      1.089037 -2.414735e-15  1.741431
# 1      1.082404 -2.414735e-15  1.296102
# 2      1.079079 -2.414735e-15  1.261487
# 3      1.079079 -2.414735e-15  1.201585
# 4      1.079079 -2.414735e-15  1.206651
# ...         ...           ...       ...
# 20635  1.555813 -1.471046e-15 -1.413673
# 20636  1.558372 -1.554312e-15 -1.432368
# 20637  1.542961 -1.582068e-15 -1.162276
# 20638  1.542961 -1.665335e-15 -1.293661
# 20639  1.527403 -1.609823e-15 -1.211589
#
# [20640 rows x 9 columns]

# %%
df1[numerical_features].skew()
# Out:
# MedInc       -0.002164
# HouseAge     -0.113089
# AveRooms      0.011794
# AveBedrms    -0.003923
# Population    0.008781
# AveOccup     -0.010867
# Latitude      0.153850
# Longitude     0.000000
# target        0.026767
# dtype: float64

# %%
df2 = df1[numerical_features]

# %% [markdown]
# ### Finding correlation and plotting heatmap

# %%
corr = df2.corr()

# %%
corr
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.149647  0.615095  -0.231318    0.025523 -0.053031
# HouseAge   -0.149647  1.000000 -0.221032  -0.133337   -0.277908 -0.010649
# AveRooms    0.615095 -0.221032  1.000000   0.159917   -0.100593 -0.012230
# AveBedrms  -0.231318 -0.133337  0.159917   1.000000    0.022477 -0.116204
# Population  0.025523 -0.277908 -0.100593   0.022477    1.000000  0.213964
# AveOccup   -0.053031 -0.010649 -0.012230  -0.116204    0.213964  1.000000
# Latitude   -0.071366  0.024328  0.125014   0.047217   -0.133011 -0.134422
# Longitude  -0.016506 -0.107547 -0.066386   0.015406    0.115722  0.153094
# target      0.682156  0.077501  0.255965  -0.120227    0.011856 -0.238206
#
#             Latitude  Longitude    target
# MedInc     -0.071366  -0.016506  0.682156
# HouseAge    0.024328  -0.107547  0.077501
# AveRooms    0.125014  -0.066386  0.255965
# AveBedrms   0.047217   0.015406 -0.120227
# Population -0.133011   0.115722  0.011856
# AveOccup   -0.134422   0.153094 -0.238206
# Latitude    1.000000  -0.934695 -0.163582
# Longitude  -0.934695   1.000000 -0.030294
# target     -0.163582  -0.030294  1.000000

# %%
plt.figure(figsize = (20,22))
sns.heatmap(corr , annot = True , fmt = '.2f',cmap = 'viridis')
plt.title('Heatmap representation of correlation of California Housing ')
# Out:
# Text(0.5, 1.0, 'Heatmap representation of correlation of California Housing ')

# %%
from sklearn.feature_selection import SelectKBest,f_regression

# %%
x = df2.drop('target',axis=1)
y = df2['target']

# %%
df2.head()
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  2.032296  0.975968  1.266038  -0.368541   -1.646905  0.188696  1.089037
# 1  2.032296 -0.568893  0.573148  -1.105422    1.313538 -1.263160  1.082404
# 2  1.768880  1.761010  1.909868   0.269369   -1.213893  0.188696  1.079079
# 3  1.119252  1.761010  0.573148   0.264627   -1.080540  0.188696  1.079079
# 4  0.189397  1.761010  0.573148   0.362216   -1.066009 -1.263160  1.079079
#
#       Longitude    target
# 0 -2.414735e-15  1.741431
# 1 -2.414735e-15  1.296102
# 2 -2.414735e-15  1.261487
# 3 -2.414735e-15  1.201585
# 4 -2.414735e-15  1.206651

# %% [markdown]
# ### Feature Selection

# %%
sk=SelectKBest(score_func=f_regression,k=3)
x_new=sk.fit_transform(x,y)
# Get selected feature names and scores
selected_features = x.columns[sk.get_support()]
feature_scores = pd.DataFrame({'Feature': x.columns, 'Score': sk.scores_}).sort_values(by='Score', ascending=False)

print("Selected Features:", selected_features)
print("\nFeature Scores:")
print(feature_scores)
# Out:
# Selected Features: Index(['MedInc', 'AveRooms', 'AveOccup'], dtype='object')
#
# Feature Scores:
#       Feature         Score
# 0      MedInc  17961.958968
# 2    AveRooms   1446.967338
# 5    AveOccup   1241.491787
# 6    Latitude    567.435834
# 3   AveBedrms    302.686848
# 1    HouseAge    124.710759
# 7   Longitude     18.957391
# 4  Population      2.901431

# %%
x.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 2.03229611,  0.97596837,  1.26603829, ...,  0.18869624,
#          1.08903747, -1.30333547],
#        [ 2.03229611, -0.56889299,  0.57314775, ..., -1.2631602 ,
#          1.0824037 , -1.30333547],
#        [ 1.76888041,  1.7610103 ,  1.90986778, ...,  0.18869624,
#          1.07907857, -1.30333547],
#        ...,
#        [-1.49827866, -0.90585048, -0.18047284, ..., -1.2631602 ,
#          1.54296058, -0.85459043],
#        [-1.32710565, -0.82037197, -0.18047284, ..., -1.2631602 ,
#          1.54296058, -0.89946494],
#        [-0.84850039, -0.99224544, -0.18047284, ...,  0.18869624,
#          1.52740292, -0.8695486 ]])

# %% [markdown]
# ## Regression Algorithm Implementation (5 marks):

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model1 = LinearRegression()

# %%
# fitting to linear regression model
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1 = model1.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae =  mean_absolute_error(y_test,y_pred1)
mse = mean_squared_error(y_test,y_pred1)
rmse = np.sqrt( mean_squared_error(y_test,y_pred1))
r2 = r2_score(y_test,y_pred1)

# %%
print (f"MAE : {mae} ")
print (f"MSE : {mse} ")
print (f"RMSE : {rmse} ")
print (f"R2 Score : {r2} ")
# Out:
# MAE : 0.44272827370528134
# MSE : 0.3404415627315328
# RMSE : 0.583473703547583
# R2 Score : 0.6587441827926087

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
model2 = RandomForestRegressor()
model2.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred2 = model2.predict(x_test)

# %%
mae2 =  mean_absolute_error(y_test,y_pred2)
mse2 = mean_squared_error(y_test,y_pred2)
rmse2 = np.sqrt( mean_squared_error(y_test,y_pred2))
r2_2 = r2_score(y_test,y_pred2)

# %%
print (f"MAE : {mae2} ")
print (f"MSE : {mse2} ")
print (f"RMSE : {rmse2} ")
print (f"R2 Score : {r2_2} ")
# Out:
# MAE : 0.28035593333487857
# MSE : 0.16356392041099177
# RMSE : 0.40443036534240573
# R2 Score : 0.836044873964128

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR

# %%
model3=SVR()

# %%
model3.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred3=model3.predict(x_test)

# %%
mae=mean_absolute_error(y_test,y_pred3)
mse=mean_squared_error(y_test,y_pred3)
rmse=np.sqrt(mean_squared_error(y_test,y_pred3))
r2=r2_score(y_test,y_pred3)

# %%
print(f"mae:{mae}")
print(f"mse:{mse}")
print(f"rmse:{rmse}")
print(f"r2:{r2}")
# Out:
# mae:0.35116524428204143
# mse:0.22687798837954637
# rmse:0.476317109056085
# r2:0.772579373947105

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
model4=GradientBoostingRegressor()

# %%
model4.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred4=model4.predict(x_test)

# %%
mae=mean_absolute_error(y_test,y_pred4)
mse=mean_squared_error(y_test,y_pred4)
rmse=np.sqrt(mean_squared_error(y_test,y_pred4))
r2=r2_score(y_test,y_pred4)

# %%
print(f"mae:{mae}")
print(f"mse:{mse}")
print(f"rmse:{rmse}")
print(f"r2:{r2}")
# Out:
# mae:0.33243337814089463
# mse:0.2053048224658757
# rmse:0.4531057519673257
# r2:0.7942041376937862

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model5 = DecisionTreeRegressor()

# %%
model5.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred5=model5.predict(x_test)

# %%
mae=mean_absolute_error(y_test,y_pred5)
mse=mean_squared_error(y_test,y_pred5)
rmse=np.sqrt(mean_squared_error(y_test,y_pred5))
r2=r2_score(y_test,y_pred5)

# %%
print(f"mae:{mae}")
print(f"mse:{mse}")
print(f"rmse:{rmse}")
print(f"r2:{r2}")
# Out:
# mae:0.37725956256926035
# mse:0.3072340421453584
# rmse:0.5542869673241094
# r2:0.6920311277946873

# %% [markdown]
# ### AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
model6 = AdaBoostRegressor()

# %%
model6.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred6=model6.predict(x_test)

# %%
mae=mean_absolute_error(y_test,y_pred6)
mse=mean_squared_error(y_test,y_pred6)
rmse=np.sqrt(mean_squared_error(y_test,y_pred6))
r2=r2_score(y_test,y_pred6)

# %%
print(f"mae:{mae}")
print(f"mse:{mse}")
print(f"rmse:{rmse}")
print(f"r2:{r2}")
# Out:
# mae:0.5232811402039474
# mse:0.4229421638931396
# rmse:0.6503400371291465
# r2:0.5760462600019451

# %% [markdown]
# ### MLP Regressor

# %%
from sklearn.neural_network import MLPRegressor

# %%
model7 = MLPRegressor()

# %%
model7.fit(x_train,y_train)
# Out:
# MLPRegressor()

# %%
y_pred7 = model7.predict(x_test)

# %%
mae=mean_absolute_error(y_test,y_pred7)
mse=mean_squared_error(y_test,y_pred7)
rmse=np.sqrt(mean_squared_error(y_test,y_pred7))
r2=r2_score(y_test,y_pred7)

# %%
print(f"mae:{mae}")
print(f"mse:{mse}")
print(f"rmse:{rmse}")
print(f"r2:{r2}")
# Out:
# mae:0.3385136918973111
# mse:0.20837619980045227
# rmse:0.45648242003438894
# r2:0.7911254143620826

# %% [markdown]
# ## Best Model

# %% [markdown]
# ### Random Forest Regressor is the best model among all
# with R2 Score : 0.836044873964128
#
# Random Forest outperforms simpler models because it combines the strengths of decision trees (flexibility, interpretability) while mitigating their weaknesses (overfitting, sensitivity to noise). Its ability to handle non-linear relationships, high-dimensional data, and noise makes it a go-to model for many regression tasks.

# %% [markdown]
# ## Worst-performing algorithm

# %% [markdown]
# ### AdaBoost Regressor is the Worst-performing algorithm
# with R2 Score : 0.5760462600019451
#
# The AdaBoost Regressor may not perform well in certain situations due to various factors related to data characteristics, model configuration, and the nature of boosting itself. AdaBoost is an ensemble method that combines the predictions of weak learners (usually decision trees) to improve performance.
